# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r'E:\PS_20174392719_1491204439457_log.csv')

# %%
df['isFraud'].head(7000000).value_counts().plot(kind='pie', figsize=(5,5), autopct='%.2f%%')
# print(df.head(63).to_string())
# Out:
# <Axes: ylabel='count'>

# %%
df['type'].value_counts().plot(kind='pie', figsize=(5,5), autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg
# 0           1   PAYMENT     9839.64  C1231006815      170136.00  \
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0             160296.36  M1979787155            0.00            0.00        0  \
# ...

# %%
sns.relplot(data=df, x='type', y='newbalanceOrig')

# %%
_ = sns.catplot(data=df, x="type", y="amount")

# %%
_ = sns.catplot(data=df, x="type", y="amount", hue="step", kind="swarm")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 _ = sns.catplot(data=df, x="type", y="amount", hue="step", kind="swarm")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3126, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3123     if plot_kws.setdefault("linewidth", 0) is None:
#    3124         plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
# -> 3126     p.plot_swarms(
#    3127         dodge=dodge,
#    3128         color=color,
#    3129         edgecolor=edgecolor,
#    3130         warn_thresh=warn_thresh,
#    3131         plot_kws=plot_kws,
#    3132     )
# ...
